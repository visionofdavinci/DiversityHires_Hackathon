# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

from openai_parser import parse_user_request

msg = "Hey, I want to watch a movie this Friday with Alice and Bob. Mood: comedy. Use their Letterboxd usernames: alice123, bob456."

parsed = parse_user_request(msg)
print(parsed)
# Out:
# Loaded environment from: ../config/.env
# USE_MOCK_AI: False
# OPENAI_API_KEY set: True
# {'error': "API call failed: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}"}

# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

from gemini_parser import parse_user_request

# Test messages
test_messages = [
    "Hey, I want to watch a movie this Friday with Alice and Bob. Mood: comedy."
]

for msg in test_messages:
    print(f"\nTesting: {msg}")
    result = parse_user_request(msg)
    print(f"Result: {result}")
    print("-" * 50)
# Out:
# Testing: Hey, I want to watch a movie this Friday with Alice and Bob. Mood: comedy.
# Parsing message: Hey, I want to watch a movie this Friday with Alice and Bob. Mood: comedy.
# Attempting Gemini parse...
# Trying model: gemini-2.0-flash-lite
# Gemini raw response: ```json
# {
#   "participants": [
#     "Alice",
#     "Bob"
#   ],
#   "date": "Friday",
#   "mood": "comedy"
# }
# ```
# Success with model: gemini-2.0-flash-lite
# Gemini parse successful
# Result: {'participants': ['Alice', 'Bob'], 'date': 'Friday', 'mood': 'comedy'}
# --------------------------------------------------
